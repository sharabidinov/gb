# %% [markdown]
# <a href="https://colab.research.google.com/github/sharabidinov/gb/blob/s_11_practise/hw_11_sharabidinov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# f(x) = 18x^3+5x^2 + 10x - 30
#
# Определить корни
#
# Найти интервалы, на которых функция возрастает
#
# Найти интервалы, на которых функция убывает
#
# Построить график
#
# Определить промежутки, на котором f > 0
#
# Определить промежутки, на котором f < 0

# %%
from math import sqrt
from sympy import *


init_printing()

init_printing()

x = Symbol('x', domain=S.Reals)

fx = 18 * x ** 3 + 5 * x ** 2 + 10 * x - 30
# Out:
#     3      2
# 18⋅x  + 5⋅x  + 10⋅x - 30

# %%
# Определить корни

solveset(fx, x, Interval(-10, 10))
# Out:
# ⎧                                           ____________________⎫
# ⎪               515                5       ╱ 135145   5⋅√252411 ⎪
# ⎪- ───────────────────────────── - ── + 3 ╱  ────── + ───────── ⎪
# ⎨           ____________________   54   ╲╱   157464      2916   ⎬
# ⎪          ╱ 135145   5⋅√252411                                 ⎪
# ⎪  2916⋅3 ╱  ────── + ─────────                                 ⎪
# ⎩       ╲╱   157464      2916                                   ⎭

# %%
# Найти интервалы, на которых функция возрастает

result = fx.diff(x)
print(result)
solve(result, x)
plot(result)
# Out:
# 54*x**2 + 10*x + 10

# %%
# Построить график
from sympy.plotting import plot

plot(fx)

# %%
# Определить промежутки, на котором f > 0

solve_univariate_inequality(fx > 0, x)
# Out:
#                                                    ____________________
#                        515                5       ╱ 135145   5⋅√252411
# x < ∞ ∧ - ───────────────────────────── - ── + 3 ╱  ────── + ─────────  < x
#                    ____________________   54   ╲╱   157464      2916
#                   ╱ 135145   5⋅√252411
#           2916⋅3 ╱  ────── + ─────────
#                ╲╱   157464      2916

# %%
# Определить промежутки, на котором f < 0

solve_univariate_inequality(fx < 0, x)
# Out:
#                                                         ____________________
#                             515                5       ╱ 135145   5⋅√252411
# -∞ < x ∧ x < - ───────────────────────────── - ── + 3 ╱  ────── + ─────────
#                         ____________________   54   ╲╱   157464      2916
#                        ╱ 135145   5⋅√252411
#                2916⋅3 ╱  ────── + ─────────
#                     ╲╱   157464      2916
